# %% [markdown]
# # My first Jupyter Notebook

# %%
a = "this is python"; print(a)
# Out:
# this is python

# %%
a <- "this is R"; cat(a)
# Out:
# this is R

# %%
import matplotlib.pyplot as p
import scipy as sc

x = sc.arange(0, 5, 0.1); y = sc.sin(x)
p.plot(x, y); p.show()
# Out:
# /var/folders/yk/n0qlgx_j7qb4_hk3sw4b5_x80000gn/T/ipykernel_92629/3881947198.py:4: DeprecationWarning: scipy.arange is deprecated and will be removed in SciPy 2.0.0, use numpy.arange instead
#   x = sc.arange(0, 5, 0.1); y = sc.sin(x)
# /var/folders/yk/n0qlgx_j7qb4_hk3sw4b5_x80000gn/T/ipykernel_92629/3881947198.py:4: DeprecationWarning: scipy.sin is deprecated and will be removed in SciPy 2.0.0, use numpy.sin instead
#   x = sc.arange(0, 5, 0.1); y = sc.sin(x)

# %%
 require(ggplot2)
library(repr)# to resize plot within jupyter - this package is part of IRKernel
options(repr.plot.width=3.3,repr.plot.height=2.5)

x <- seq(0, 5, 0.1); y <- sin(x)
qplot(x, y, geom = "line") # large figure
# Out:
# Loading required package: ggplot2
# plot without title
